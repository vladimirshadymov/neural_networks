# %%
# %matplotlib inline

# %%
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple
from collections import deque
from itertools import count
from copy import deepcopy
from PIL import Image
from tqdm import tqdm_notebook

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T
from torch.distributions import Categorical

# создаем энвайронмент с игрой
env = gym.make('Breakout-v0').unwrapped

# настраиваем matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display    
print("Is python : {}".format(is_ipython))

# выбираем девайс для игры
device = torch.device("cuda:2" if torch.cuda.is_available() else "cpu")
print("Device : {}".format(device))

# запоминаем, сколько действий в игре
ACTIONS_NUM = env.action_space.n
print("Number of actions : {}".format(ACTIONS_NUM))
# Out:
# /home/v.shadymov/anaconda3/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# Is python : True
# Device : cuda:2
# Number of actions : 4

# %%
STATE_SIZE = 4
STATE_W = 84
STATE_H = 84
MEMSIZE = 50000

# Задание 1. Необходимо реализовать класс для хранения состояния игры. 
class StateHolder:
    def __init__(self, capacity=STATE_SIZE):
        self.capacity = capacity
        self.state = None
        
    def reset(self):
        self.state = None
        
    def push(self, new_screen):
        new_screen = new_screen.squeeze(0)
        if self.state is None: 
            self.state = torch.cat([new_screen for i in range(self.capacity)])
        else:
            self.state = torch.cat((self.state, new_screen))[1:]
        
    def get_state(self):
        if self.state is None: return None
        else: return self.state.unsqueeze(0)
    
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))

class ReplayMemory:

    def __init__(self, capacity = MEMSIZE):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        #Положить переход в память
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        #Получить сэмпл из памяти
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
# Задание 2. Собрать архитектуру сети (DQN).
class DQN(nn.Module):
    def __init__(self):
        super(DQN, self).__init__()
        self.conv1 = nn.Conv2d(4, 16, kernel_size=5, stride=1)
        #self.bn1 = nn.BatchNorm2d(16)
        self.maxpool1 = nn.MaxPool2d(2, 2)
        
        self.conv2 = nn.Conv2d(16, 32, kernel_size=5, stride=1)
        #self.bn2 = nn.BatchNorm2d(32)
        self.maxpool2 = nn.MaxPool2d(2, 2)
        
        self.conv3 = nn.Conv2d(32, 32, kernel_size=5, stride=1)
        #self.bn3 = nn.BatchNorm2d(32)
        self.maxpool3 = nn.MaxPool2d(2, 2)
        
        self.fc = nn.Linear(1568, 512)
        #self.bn4 = nn.BatchNorm1d(1)
        self.head = nn.Linear(512, ACTIONS_NUM)
        
        #self.relu = nn.ReLU()
        #self.tanh = nn.Tanh()
        #self.sigmoid = nn.Sigmoid()
        #self.elu = nn.ELU()
        self.tanhshrink = nn.Tanhshrink()

    def forward(self, x):
        x = x.to(torch.float32)
        x = self.relu(self.maxpool1(self.conv1(x)))
        x = self.relu(self.maxpool2(self.conv2(x)))
        x = self.relu(self.maxpool3(self.conv3(x)))
        x = x.view(x.size(0), -1).unsqueeze(1)
        x = self.fc(x)
        x = self.tanhshrink(x)
        return self.head(x).squeeze(1)

# %%
# Тут блок с кодом, генерирующим 1 кадр игры
resize = T.Compose([T.ToPILImage(),
                    T.Resize( (STATE_W, STATE_H), interpolation=Image.CUBIC),
                    T.ToTensor()])

def get_screen():
    screen = env.render(mode='rgb_array')
    screen = np.dot(screen[...,:3], [0.299, 0.587, 0.114])
    screen = screen[30:195,:]
    screen = np.ascontiguousarray(screen, dtype=np.uint8).reshape(screen.shape[0],screen.shape[1],1)
    return resize(screen).mul(255).type(torch.ByteTensor).to(device).detach().unsqueeze(0)

env.reset()
plt.figure()
plt.imshow(get_screen().cpu().reshape(-1,84).numpy(),
           interpolation='none')
plt.title('Example extracted screen')
plt.show()

# %%
policy_net = DQN().to(device)
target_net = DQN().to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=1e-4)

memory = ReplayMemory()
state_holder = StateHolder()

def select_action(state, eps_threshold):
    global steps_done
    sample = random.random()
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            return policy_net(state).max(1)[1].view(1, 1)
    else:
        return torch.tensor([[random.randrange(ACTIONS_NUM)]], device=device, dtype=torch.long)

train_rewards = []

mean_size = 100
mean_step = 1

def plot_rewards(rewards = train_rewards, name = "Train"):
    plt.figure(2)
    plt.clf()
    plt.title(name)
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.plot(rewards)
    # Строим график среднего вознаграждения по 100 последним эпизодам
    if len(rewards) > mean_size:
        means = np.array([rewards[i:i+mean_size:] for i in range(0, len(rewards) - mean_size, mean_step)]).mean(1)
        means = np.concatenate((np.zeros(mean_size - 1), means))
        plt.plot(means)

# %%
BATCH_SIZE = 32
GAMMA = 0.99

def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    # выбираем новый батч
    transitions = memory.sample(BATCH_SIZE)
    batch = Transition(*zip(*transitions))
    
    # Для всех состояний считаем маску не финальнсти и конкантенируем их
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.uint8)

    non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])
    
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Считаем Q(s_t, a) - модель дает Q(s_t), затем мы выбираем
    # колонки, которые соответствуют нашим действиям на щаге
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Подсчитываем ценность состяония V(s_{t+1}) для всех последующмх состояний.
    next_state_values = torch.zeros(BATCH_SIZE, device=device).detach()
    next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach() # берем значение максимума
    
    # Считаем ожидаемое значение функции оценки ценности действия  Q-values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Считаем ошибку Huber loss
    loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))
    
    # Оптимизация модели
    optimizer.zero_grad()
    loss.backward()
    for param in policy_net.parameters():
        param.grad.data.clamp_(-1, 1)
    optimizer.step()
    
    del non_final_mask
    del non_final_next_states
    del state_batch
    del action_batch
    del reward_batch
    del state_action_values
    del next_state_values
    del expected_state_action_values
    del loss

# %%
# количество эпизодов, которые играем
NUM_EPISODES = 100000 

# количество кадров, между которыми обучаем модель
OPTIMIZE_MODEL_STEP = 5
# количество кадров, между которыми обновляем target-модель
TARGET_UPDATE = 10000 

# несколько шагов для разогрева модели()
STEPS_BEFORE_TRAIN = 50000 

# параметры для e-greedy стратегии выбора действия
EPS_START = 1
EPS_END = 0.1
EPS_DECAY = 1000000 #10^6

policy_net.train()
target_net.eval()

state_holder = StateHolder()
test_rewards = []

# Общее число 
steps_done = 0

# Задание 3. Заполнить пропуски в нижеприведенном коде.

for iter in tqdm_notebook(range(NUM_EPISODES)):
    
    # Инициализации разлинычх переменных
    # env - среды
    # state_holder - хранителя состояния
    # lives - количества жизней в начале эпизода игры
    env.reset()
    state_holder.push(get_screen())
    state = state_holder.get_state()
    lives_counter = env.ale.lives()
    ep_rewards = []
    
    for t in count():
        
        # Рассчет eps_threshold'а для e-greedy
        eps_threshold = EPS_END + (EPS_START - EPS_END) * math.exp(-1.*steps_done/EPS_DECAY)
            
        action = select_action(state, eps_threshold)
        # Шаг одного кадра игры 
        _, reward, done, _ = env.step(action.item())
        # где:
        # reward - награда, полученная в рамках последнего действия
        # done - флаг окончания эпизода
        ep_rewards.append(reward)
        reward = torch.tensor([reward], device=device)
        
        
        # Работа с ReplayMemory
        state_holder.push(get_screen()) #обновляем держатель состояний после действия
        
        if done:
            next_state = None
            memory.push(state, action, next_state, reward)
        elif lives_counter>env.ale.lives():
            lives_counter = env.ale.lives()
            next_state = None
            memory.push(state, action, next_state, reward)
            state = state_holder.get_state()
        else:
            next_state = state_holder.get_state()
            memory.push(state, action, next_state, reward)
            state = next_state
        
        
        # Шаг оптимизации
        if (steps_done > STEPS_BEFORE_TRAIN) and steps_done % OPTIMIZE_MODEL_STEP == 0:
            optimize_model()
        
        # Шаг обновления target'сети
        if steps_done % TARGET_UPDATE == 0:
            print("Target net updated!")
            target_net.load_state_dict(policy_net.state_dict())
        
        # Код завершающий эпизод игры/обучения
        if done:
            train_rewards.append(np.sum(ep_rewards))
            # Суммарный reward(не дисконтированный) за последний эпизод
            print("Episode score : {}".format(train_rewards[-1]))
            # Средний reward по последним 100 эпизодам
            print("Mean score : {}".format(np.mean(train_rewards[-100:])))
            print("eps_threshold:", eps_threshold)
            
            plot_rewards()
            break 
    if np.mean(train_rewards[-100:]) > 35:
        break
# Out:
# Episode score : 1.0
# Mean score : 1.01
# eps_threshold: 0.999772328801621
# Episode score : 0.0
# Mean score : 1.01
# eps_threshold: 0.9996184808877675
# Episode score : 5.0
# Mean score : 1.04
# eps_threshold: 0.9992020539413936
# Episode score : 4.0
# Mean score : 1.07
# eps_threshold: 0.9988640175239406
# Episode score : 0.0
# Mean score : 1.06
# eps_threshold: 0.9987085274991839
# Episode score : 2.0
# Mean score : 1.08
# eps_threshold: 0.9984380569402679
# Episode score : 0.0
# Mean score : 1.08
# eps_threshold: 0.9982790474769421
# Episode score : 1.0
# Mean score : 1.09
# eps_threshold: 0.9980904286826384
# Episode score : 1.0
# Mean score : 1.1
# eps_threshold: 0.997877606471469
# Episode score : 0.0
# Mean score : 1.1
# eps_threshold: 0.9977267757037209
# Episode score : 3.0
# Mean score : 1.12
# eps_threshold: 0.9974099340777347
# Episode score : 3.0
# Mean score : 1.12
# eps_threshold: 0.9971156318875548
# Episode score : 3.0
# Mean score : 1.12
# eps_threshold: 0.9968250135055434
# Episode score : 1.0
# Mean score : 1.12
# eps_threshold: 0.9966160776193727
# Episode score : 1.0
# Mean score : 1.12
# eps_threshold: 0.9964071904095924
# Episode score : 2.0
# Mean score : 1.13
# eps_threshold: 0.9961607123245196
# Episode score : 2.0
# Mean score : 1.15
# eps_threshold: 0.9959214693546867
# Episode score : 0.0
# Mean score : 1.14
# eps_threshold: 0.9957378242777326
# Episode score : 0.0
# Mean score : 1.13
# eps_threshold: 0.995573919253657
# Episode score : 1.0
# Mean score : 1.13
# eps_threshold: 0.9953634841097302
# Episode score : 3.0
# Mean score : 1.14
# eps_threshold: 0.9950707481153698
# Episode score : 0.0
# Mean score : 1.14
# eps_threshold: 0.9949177041030781
# Episode score : 2.0
# Mean score : 1.14
# eps_threshold: 0.9946940026409002
# Episode score : 0.0
# Mean score : 1.14
# eps_threshold: 0.9945311831494428
# Episode score : 0.0
# Mean score : 1.14
# eps_threshold: 0.994365710187281
# Episode score : 0.0
# Mean score : 1.13
# eps_threshold: 0.9942038446430108
# Episode score : 3.0
# Mean score : 1.12
# eps_threshold: 0.9938962914226404
# Episode score : 0.0
# Mean score : 1.11
# eps_threshold: 0.9937425544822716
# Episode score : 1.0
# Mean score : 1.12
# eps_threshold: 0.9935343367253878
# Episode score : 3.0
# Mean score : 1.14
# eps_threshold: 0.993223440875223
# Episode score : 1.0
# Mean score : 1.15
# eps_threshold: 0.9930198091456027
# Episode score : 1.0
# Mean score : 1.16
# eps_threshold: 0.9928072957211267
# Episode score : 0.0
# Mean score : 1.16
# eps_threshold: 0.9926492828143388
# Episode score : 0.0
# Mean score : 1.14
# eps_threshold: 0.9924966528372126
# Episode score : 3.0
# Mean score : 1.16
# eps_threshold: 0.9922200217548661
# Episode score : 1.0
# Mean score : 1.13
# eps_threshold: 0.9919889666921539
# Episode score : 0.0
# Mean score : 1.13
# eps_threshold: 0.9918302067861334
# Episode score : 2.0
# Mean score : 1.15
# eps_threshold: 0.9915573484923049
# Episode score : 1.0
# Mean score : 1.14
# eps_threshold: 0.9913318130145774
# Episode score : 2.0
# Mean score : 1.15
# eps_threshold: 0.9910635625125859
# Target net updated!
# Episode score : 0.0
# Mean score : 1.12
# eps_threshold: 0.9909183309885871
# Episode score : 1.0
# Mean score : 1.13
# eps_threshold: 0.9907000827339978
# Episode score : 0.0
# Mean score : 1.13
# eps_threshold: 0.9905486765898199
# Episode score : 2.0
# Mean score : 1.15
# eps_threshold: 0.9903082609047187
# Episode score : 2.0
# Mean score : 1.16
# eps_threshold: 0.9900554492595746
# Episode score : 2.0
# Mean score : 1.15
# eps_threshold: 0.9897849135265145
# Episode score : 0.0
# Mean score : 1.12
# eps_threshold: 0.9896390007658696
# Episode score : 0.0
# Mean score : 1.12
# eps_threshold: 0.9894788801570189
# Episode score : 0.0
# Mean score : 1.12
# eps_threshold: 0.9893125631575536
# Episode score : 1.0
# Mean score : 1.12
# eps_threshold: 0.9890964864590884
# Episode score : 1.0
# Mean score : 1.11
# eps_threshold: 0.9889053512622696
# Episode score : 0.0
# Mean score : 1.1
# eps_threshold: 0.9887649153115026
# Episode score : 1.0
# Mean score : 1.09
# eps_threshold: 0.9885560800955033
# Episode score : 4.0
# Mean score : 1.11
# eps_threshold: 0.9881962877459333
# Episode score : 0.0
# Mean score : 1.1
# eps_threshold: 0.9880302105688248
# Episode score : 2.0
# Mean score : 1.12
# eps_threshold: 0.9877913625686782
# Episode score : 0.0
# Mean score : 1.09
# eps_threshold: 0.9876342374034908
# Episode score : 2.0
# Mean score : 1.11
# eps_threshold: 0.9873910589394131
# Episode score : 2.0
# Mean score : 1.12
# eps_threshold: 0.9871479470971072
# Episode score : 2.0
# Mean score : 1.14
# eps_threshold: 0.9868907114934143
# Episode score : 1.0
# Mean score : 1.14
# eps_threshold: 0.986685863399925
# Episode score : 1.0
# Mean score : 1.15
# eps_threshold: 0.986497905921081
# Episode score : 0.0
# Mean score : 1.15
# eps_threshold: 0.9863472140862433
# Episode score : 0.0
# Mean score : 1.13
# eps_threshold: 0.9861930030877383
# Episode score : 2.0
# Mean score : 1.13
# eps_threshold: 0.9859174399160723
# Episode score : 2.0
# Mean score : 1.13
# eps_threshold: 0.9856676464205542
# Episode score : 0.0
# Mean score : 1.12
# eps_threshold: 0.9854976145560227
# Episode score : 1.0
# Mean score : 1.11
# eps_threshold: 0.9852683003713215
# Episode score : 1.0
# Mean score : 1.1
# eps_threshold: 0.9850797583037855
# Episode score : 1.0
# Mean score : 1.11
# eps_threshold: 0.984855861449081
# Episode score : 1.0
# Mean score : 1.1
# eps_threshold: 0.9846311366015367
# Episode score : 0.0
# Mean score : 1.08
# eps_threshold: 0.9844745707468452
# Episode score : 0.0
# Mean score : 1.05
# eps_threshold: 0.9843259914999658
# Episode score : 1.0
# Mean score : 1.05
# eps_threshold: 0.9841243881575583
# Episode score : 3.0
# Mean score : 1.05
# eps_threshold: 0.9838556551930385
# Episode score : 1.0
# Mean score : 1.06
# eps_threshold: 0.9836621119983047
# Episode score : 0.0
# Mean score : 1.06
# eps_threshold: 0.9835030671326123
# Episode score : 2.0
# Mean score : 1.07
# eps_threshold: 0.9832627869779347
# Episode score : 0.0
# Mean score : 1.06
# eps_threshold: 0.9831046970885329
# Episode score : 1.0
# Mean score : 1.07
# eps_threshold: 0.9829174987364765
# Episode score : 0.0
# Mean score : 1.07
# eps_threshold: 0.9827665327521521
# Episode score : 2.0
# Mean score : 1.09
# eps_threshold: 0.9825211577647506
# Target net updated!
# Episode score : 5.0
# Mean score : 1.12
# eps_threshold: 0.9821258768356114
# Episode score : 0.0
# Mean score : 1.12
# eps_threshold: 0.9819838660016197
# Episode score : 0.0
# Mean score : 1.11
# eps_threshold: 0.9818251231930207
# Episode score : 4.0
# Mean score : 1.13
# eps_threshold: 0.9814856858664696
# Episode score : 0.0
# Mean score : 1.13
# eps_threshold: 0.9813296767072891
# Episode score : 1.0
# Mean score : 1.12
# eps_threshold: 0.9811120151594501
# Episode score : 0.0
# Mean score : 1.12
# eps_threshold: 0.9809578340480379
# Episode score : 2.0
# Mean score : 1.14
# eps_threshold: 0.9806918249515507
# Episode score : 2.0
# Mean score : 1.16
# eps_threshold: 0.980416211546089
# Episode score : 0.0
# Mean score : 1.16
# eps_threshold: 0.9802727153988607
# Episode score : 2.0
# Mean score : 1.17
# eps_threshold: 0.9800060331704927
# Episode score : 1.0
# Mean score : 1.17
# eps_threshold: 0.9798159723946307
# Episode score : 3.0
# Mean score : 1.17
# eps_threshold: 0.9795212834070398
# Episode score : 0.0
# Mean score : 1.17
# eps_threshold: 0.9793735362425369
# Episode score : 0.0
# Mean score : 1.16
# eps_threshold: 0.9792126256091764
# Episode score : 2.0
# Mean score : 1.18
# eps_threshold: 0.9789489013821058
# Episode score : 3.0
# Mean score : 1.21
# eps_threshold: 0.978663289403617
# Episode score : 0.0
# Mean score : 1.2
# eps_threshold: 0.9785086582726207
# Episode score : 1.0
# Mean score : 1.2
# eps_threshold: 0.9783083811309963
# Episode score : 3.0
# Mean score : 1.23
# eps_threshold: 0.9780054170038229
# Episode score : 4.0
# Mean score : 1.22
# eps_threshold: 0.977656918034895
# Episode score : 0.0
# Mean score : 1.18
# eps_threshold: 0.9774910565517904
# Episode score : 1.0
# Mean score : 1.19
# eps_threshold: 0.977313821259734
# Episode score : 2.0
# Mean score : 1.19
# eps_threshold: 0.977064699511459
# Episode score : 0.0
# Mean score : 1.19
# eps_threshold: 0.9768989499470785
# Episode score : 0.0
# Mean score : 1.18
# eps_threshold: 0.9767507665463875
# Episode score : 1.0
# Mean score : 1.18
# eps_threshold: 0.9765587791519009
# Episode score : 1.0
# Mean score : 1.19
# eps_threshold: 0.9763519356885098
# Episode score : 1.0
# Mean score : 1.17
# eps_threshold: 0.9761407603196628
# Episode score : 3.0
# Mean score : 1.17
# eps_threshold: 0.9758656953083892
# Episode score : 0.0
# Mean score : 1.14
# eps_threshold: 0.9757098050892655
# Episode score : 2.0
# Mean score : 1.15
# eps_threshold: 0.9754698934720635
# Episode score : 1.0
# Mean score : 1.15
# eps_threshold: 0.9752650574837364
# Episode score : 1.0
# Mean score : 1.14
# eps_threshold: 0.9750620195437119
# Episode score : 0.0
# Mean score : 1.12
# eps_threshold: 0.9749027727480529
# Episode score : 2.0
# Mean score : 1.14
# eps_threshold: 0.9746595835820892
# Episode score : 0.0
# Mean score : 1.14
# eps_threshold: 0.9745021590256795
# Episode score : 2.0
# Mean score : 1.15
# eps_threshold: 0.9742617039960295
# Episode score : 0.0
# Mean score : 1.12
# eps_threshold: 0.9741192109517768
# Episode score : 0.0
# Mean score : 1.12
# eps_threshold: 0.973974993180263
# Episode score : 0.0
# Mean score : 1.1
# eps_threshold: 0.9738238085842874
# Episode score : 0.0
# Mean score : 1.1
# eps_threshold: 0.9736787658709407
# Episode score : 2.0
# Mean score : 1.12
# eps_threshold: 0.9734367903679488
# Target net updated!
# Episode score : 0.0
# Mean score : 1.12
# eps_threshold: 0.9732752195074962
# Episode score : 1.0
# Mean score : 1.1
# eps_threshold: 0.9730691508727477
# Episode score : 1.0
# Mean score : 1.11
# eps_threshold: 0.9728587665597155
# Episode score : 3.0
# Mean score : 1.13
# eps_threshold: 0.972555937111667
# Episode score : 0.0
# Mean score : 1.1
# eps_threshold: 0.9723858052923218
# Episode score : 0.0
# Mean score : 1.09
# eps_threshold: 0.9722218121767627
# Episode score : 1.0
# Mean score : 1.09
# eps_threshold: 0.9720220962501206
# Episode score : 2.0
# Mean score : 1.11
# eps_threshold: 0.9717701182768752
# Episode score : 0.0
# Mean score : 1.11
# eps_threshold: 0.9716088557222402
# Episode score : 2.0
# Mean score : 1.1
# eps_threshold: 0.9713726817253615
# Episode score : 3.0
# Mean score : 1.12
# eps_threshold: 0.9710869183535106
# Episode score : 1.0
# Mean score : 1.13
# eps_threshold: 0.9709040093067783
# Episode score : 0.0
# Mean score : 1.11
# eps_threshold: 0.9707385532638318
# Episode score : 0.0
# Mean score : 1.1
# eps_threshold: 0.9705844461787836
# Episode score : 1.0
# Mean score : 1.09
# eps_threshold: 0.970400772238922
# Episode score : 1.0
# Mean score : 1.1
# eps_threshold: 0.9702127859753656
# Episode score : 1.0
# Mean score : 1.1
# eps_threshold: 0.9699935199819755
# Episode score : 2.0
# Mean score : 1.12
# eps_threshold: 0.9697551744123346
# Episode score : 0.0
# Mean score : 1.1
# eps_threshold: 0.9696099374258336
# Episode score : 1.0
# Mean score : 1.09
# eps_threshold: 0.9694003866827927
# Episode score : 4.0
# Mean score : 1.11
# eps_threshold: 0.9690770298870398
# Episode score : 0.0
# Mean score : 1.11
# eps_threshold: 0.9689206100998633
# Episode score : 1.0
# Mean score : 1.12
# eps_threshold: 0.9687225187840287
# Episode score : 3.0
# Mean score : 1.15
# eps_threshold: 0.9684237296322474
# Episode score : 0.0
# Mean score : 1.14
# eps_threshold: 0.968276978422766
# Episode score : 1.0
# Mean score : 1.14
# eps_threshold: 0.9680937913072393
# Episode score : 0.0
# Mean score : 1.14
# eps_threshold: 0.9679297370842946
# Episode score : 0.0
# Mean score : 1.13
# eps_threshold: 0.9677717882459255
# Episode score : 0.0
# Mean score : 1.09
# eps_threshold: 0.9676277500845749
# Episode score : 3.0
# Mean score : 1.12
# eps_threshold: 0.9673406128231352
# Episode score : 0.0
# Mean score : 1.1
# eps_threshold: 0.9671940446449281
# Episode score : 0.0
# Mean score : 1.1
# eps_threshold: 0.9670457671413817
# Episode score : 7.0
# Mean score : 1.15
# eps_threshold: 0.9665560246482292
# Episode score : 2.0
# Mean score : 1.15
# eps_threshold: 0.9663212197830459
# Episode score : 2.0
# Mean score : 1.15
# eps_threshold: 0.9660778177198783
# Episode score : 1.0
# Mean score : 1.15
# eps_threshold: 0.9658812403676293
# Episode score : 1.0
# Mean score : 1.15
# eps_threshold: 0.9656855733185158
# Episode score : 4.0
# Mean score : 1.19
# eps_threshold: 0.9653549445836169
# Episode score : 2.0
# Mean score : 1.21
# eps_threshold: 0.9651178698095283
# Episode score : 0.0
# Mean score : 1.19
# eps_threshold: 0.9649725422152601
# Episode score : 1.0
# Mean score : 1.18
# eps_threshold: 0.9647718918618071
# Target net updated!
# Episode score : 1.0
# Mean score : 1.19
# eps_threshold: 0.9645730171981419
# Episode score : 0.0
# Mean score : 1.18
# eps_threshold: 0.9644260522775904
# Episode score : 4.0
# Mean score : 1.21
# eps_threshold: 0.9641010891788252
# Episode score : 3.0
# Mean score : 1.23
# eps_threshold: 0.9638384423720521
# Episode score : 0.0
# Mean score : 1.22
# eps_threshold: 0.9636967844837674
# Episode score : 1.0
# Mean score : 1.23
# eps_threshold: 0.9634869316632882
# Episode score : 0.0
# Mean score : 1.23
# eps_threshold: 0.9633306546721515
# Episode score : 2.0
# Mean score : 1.24
# eps_threshold: 0.9630889559282465
# Episode score : 1.0
# Mean score : 1.22
# eps_threshold: 0.9628844280831985
# Episode score : 2.0
# Mean score : 1.23
# eps_threshold: 0.962642854265248
# Episode score : 3.0
# Mean score : 1.26
# eps_threshold: 0.9623358080665958
# Episode score : 0.0
# Mean score : 1.24
# eps_threshold: 0.962176290697915
# Episode score : 0.0
# Mean score : 1.24
# eps_threshold: 0.9620288711569356
# Episode score : 2.0
# Mean score : 1.25
# eps_threshold: 0.9617927076021232
# Episode score : 2.0
# Mean score : 1.27
# eps_threshold: 0.9615307624366946
# Episode score : 1.0
# Mean score : 1.26
# eps_threshold: 0.9613283264946768
# Episode score : 1.0
# Mean score : 1.22
# eps_threshold: 0.9611457442438623
# Episode score : 1.0
# Mean score : 1.23
# eps_threshold: 0.9609545911074234
# Episode score : 2.0
# Mean score : 1.25
# eps_threshold: 0.9607221647467951
# Episode score : 1.0
# Mean score : 1.22
# eps_threshold: 0.9605225003665374
# Episode score : 4.0
# Mean score : 1.26
# eps_threshold: 0.9601955639382537
# Episode score : 2.0
# Mean score : 1.27
# eps_threshold: 0.9599401237905036
# Episode score : 1.0
# Mean score : 1.28
# eps_threshold: 0.9597586955657347
# Episode score : 0.0
# Mean score : 1.26
# eps_threshold: 0.959603093324265
# Episode score : 0.0
# Mean score : 1.24
# eps_threshold: 0.9594578326763636
# Episode score : 2.0
# Mean score : 1.26
# eps_threshold: 0.9592395581089075
# Episode score : 0.0
# Mean score : 1.24
# eps_threshold: 0.9590900634322106
# Episode score : 0.0
# Mean score : 1.23
# eps_threshold: 0.9589414537063486
# Episode score : 0.0
# Mean score : 1.2
# eps_threshold: 0.9587774115552149
# Episode score : 0.0
# Mean score : 1.2
# eps_threshold: 0.9586168351936118
# Episode score : 0.0
# Mean score : 1.2
# eps_threshold: 0.9584674488612759
# Episode score : 0.0
# Mean score : 1.18
# eps_threshold: 0.9583129386268192
# Episode score : 2.0
# Mean score : 1.17
# eps_threshold: 0.9580760769441741
# Episode score : 0.0
# Mean score : 1.17
# eps_threshold: 0.9579302164095902
# Episode score : 1.0
# Mean score : 1.17
# eps_threshold: 0.9577226224171054
# Episode score : 3.0
# Mean score : 1.17
# eps_threshold: 0.9574293314358552
# Episode score : 2.0
# Mean score : 1.15
# eps_threshold: 0.9571944279822846
# Episode score : 1.0
# Mean score : 1.16
# eps_threshold: 0.9569827271047076
# Episode score : 1.0
# Mean score : 1.16
# eps_threshold: 0.9567847869577135
# Episode score : 0.0
# Mean score : 1.14
# eps_threshold: 0.9566271530596766
# Episode score : 1.0
# Mean score : 1.15
# eps_threshold: 0.9564198743703692
# Episode score : 1.0
# Mean score : 1.16
# eps_threshold: 0.9562169269103674
# Target net updated!
# Episode score : 3.0
# Mean score : 1.18
# eps_threshold: 0.955929286349246
# Episode score : 3.0
# Mean score : 1.2
# eps_threshold: 0.9556434537043141
# Episode score : 0.0
# Mean score : 1.19
# eps_threshold: 0.9554928737078906
# Episode score : 1.0
# Mean score : 1.17
# eps_threshold: 0.9552875800544245
# Episode score : 1.0
# Mean score : 1.18
# eps_threshold: 0.9550908865316342
# Episode score : 1.0
# Mean score : 1.17
# eps_threshold: 0.9548916735642843
# Episode score : 0.0
# Mean score : 1.16
# eps_threshold: 0.9547386616496911
# Episode score : 8.0
# Mean score : 1.23
# eps_threshold: 0.9543131077679011
# Episode score : 0.0
# Mean score : 1.23
# eps_threshold: 0.9541610535679438
# Episode score : 2.0
# Mean score : 1.23
# eps_threshold: 0.9539415623830022
# Episode score : 0.0
# Mean score : 1.23
# eps_threshold: 0.9537835978061352
# Episode score : 3.0
# Mean score : 1.24
# eps_threshold: 0.953509577253891
# Episode score : 0.0
# Mean score : 1.24
# eps_threshold: 0.9533627862309932
# Episode score : 5.0
# Mean score : 1.29
# eps_threshold: 0.9530138322173849
# Episode score : 4.0
# Mean score : 1.33
# eps_threshold: 0.9527076552136794
# Episode score : 0.0
# Mean score : 1.33
# eps_threshold: 0.9525635597963541
# Episode score : 3.0
# Mean score : 1.34
# eps_threshold: 0.9522797033956556
# Episode score : 0.0
# Mean score : 1.34
# eps_threshold: 0.9521322717601723
# Episode score : 1.0
# Mean score : 1.34
# eps_threshold: 0.9519184134003075
# Episode score : 2.0
# Mean score : 1.35
# eps_threshold: 0.9516577662468553
# Episode score : 4.0
# Mean score : 1.36
# eps_threshold: 0.9512797141324217
# Episode score : 0.0
# Mean score : 1.36
# eps_threshold: 0.9511333066129986
# Episode score : 0.0
# Mean score : 1.36
# eps_threshold: 0.9509903282280082
# Episode score : 2.0
# Mean score : 1.37
# eps_threshold: 0.9507299650251722
# Episode score : 3.0
# Mean score : 1.38
# eps_threshold: 0.9504705319513943
# Episode score : 3.0
# Mean score : 1.41
# eps_threshold: 0.9501763200489334
# Episode score : 1.0
# Mean score : 1.4
# eps_threshold: 0.9499714522433638
# Episode score : 1.0
# Mean score : 1.38
# eps_threshold: 0.949767483572045
# Episode score : 0.0
# Mean score : 1.37
# eps_threshold: 0.9495958478761523
# Episode score : 0.0
# Mean score : 1.37
# eps_threshold: 0.949440386061181
# Episode score : 1.0
# Mean score : 1.38
# eps_threshold: 0.9492322986583436
# Episode score : 5.0
# Mean score : 1.42
# eps_threshold: 0.9488773937378003
# Episode score : 3.0
# Mean score : 1.44
# eps_threshold: 0.9485956132212334
# Episode score : 3.0
# Mean score : 1.46
# eps_threshold: 0.9482961118348711
# Episode score : 1.0
# Mean score : 1.45
# eps_threshold: 0.9481018742663113
# Episode score : 7.0
# Mean score : 1.52
# eps_threshold: 0.9476058797624031
# Target net updated!
# Episode score : 0.0
# Mean score : 1.51
# eps_threshold: 0.9474584091696381
# Episode score : 2.0
# Mean score : 1.49
# eps_threshold: 0.9472414875840383
# Episode score : 0.0
# Mean score : 1.49
# eps_threshold: 0.9470923862035299
# Episode score : 0.0
# Mean score : 1.48
# eps_threshold: 0.9469475457896973
# Episode score : 1.0
# Mean score : 1.46
# eps_threshold: 0.9467595443034691
# Episode score : 2.0
# Mean score : 1.48
# eps_threshold: 0.946499629022405
# Episode score : 3.0
# Mean score : 1.5
# eps_threshold: 0.9462313311674616
# Episode score : 0.0
# Mean score : 1.5
# eps_threshold: 0.9460722546308651
# Episode score : 1.0
# Mean score : 1.51
# eps_threshold: 0.9458912145403547
# Episode score : 1.0
# Mean score : 1.52
# eps_threshold: 0.9456932991531557
# Episode score : 2.0
# Mean score : 1.51
# eps_threshold: 0.9454396292158028
# Episode score : 0.0
# Mean score : 1.51
# eps_threshold: 0.9452807015051832
# Episode score : 0.0
# Mean score : 1.51
# eps_threshold: 0.9451395514143924
# Episode score : 1.0
# Mean score : 1.45
# eps_threshold: 0.944940966954398
# Episode score : 4.0
# Mean score : 1.47
# eps_threshold: 0.9445566062631221
# Episode score : 2.0
# Mean score : 1.47
# eps_threshold: 0.9443421161265317
# Episode score : 3.0
# Mean score : 1.49
# eps_threshold: 0.9440542445498259
# Episode score : 5.0
# Mean score : 1.53
# eps_threshold: 0.9436888481759598
# Episode score : 2.0
# Mean score : 1.51
# eps_threshold: 0.9434265017411622
# Episode score : 0.0
# Mean score : 1.49
# eps_threshold: 0.943289034425269
# Episode score : 1.0
# Mean score : 1.5
# eps_threshold: 0.9431153347758555
# Episode score : 2.0
# Mean score : 1.51
# eps_threshold: 0.9428877243642543
# Episode score : 0.0
# Mean score : 1.5
# eps_threshold: 0.9427216918372955
# Episode score : 1.0
# Mean score : 1.51
# eps_threshold: 0.9425464239538851
# Episode score : 0.0
# Mean score : 1.47
# eps_threshold: 0.9424032032359189
# Episode score : 0.0
# Mean score : 1.44
# eps_threshold: 0.9422574800871748
# Episode score : 1.0
# Mean score : 1.45
# eps_threshold: 0.9420511522807419
# Episode score : 1.0
# Mean score : 1.45
# eps_threshold: 0.941882758890186
# Episode score : 1.0
# Mean score : 1.46
# eps_threshold: 0.9416899898113023
# Episode score : 3.0
# Mean score : 1.47
# eps_threshold: 0.9414047052632192
# Episode score : 6.0
# Mean score : 1.52
# eps_threshold: 0.9409841080686486
# Episode score : 1.0
# Mean score : 1.51
# eps_threshold: 0.9408176096991335
# Episode score : 1.0
# Mean score : 1.49
# eps_threshold: 0.9406183595377117
# Episode score : 0.0
# Mean score : 1.49
# eps_threshold: 0.9404721046676947
# Episode score : 0.0
# Mean score : 1.49
# eps_threshold: 0.9403267155701068
# Episode score : 3.0
# Mean score : 1.5
# eps_threshold: 0.9400452532679587
# Episode score : 1.0
# Mean score : 1.49
# eps_threshold: 0.9398327487018431
# Episode score : 0.0
# Mean score : 1.48
# eps_threshold: 0.9396866305162197
# Episode score : 1.0
# Mean score : 1.48
# eps_threshold: 0.9394792535305942
# Episode score : 3.0
# Mean score : 1.5
# eps_threshold: 0.9391980750806814
# Target net updated!
# Episode score : 3.0
# Mean score : 1.51
# eps_threshold: 0.9389329303840245
# Episode score : 0.0
# Mean score : 1.5
# eps_threshold: 0.9387928402824993
# Episode score : 1.0
# Mean score : 1.47
# eps_threshold: 0.9385999401136041
# Episode score : 2.0
# Mean score : 1.47
# eps_threshold: 0.9383676800996896
# Episode score : 3.0
# Mean score : 1.49
# eps_threshold: 0.938060055613639
# Episode score : 0.0
# Mean score : 1.49
# eps_threshold: 0.9379167595962878
# Episode score : 1.0
# Mean score : 1.5
# eps_threshold: 0.9377408155515439
# Episode score : 1.0
# Mean score : 1.49
# eps_threshold: 0.9375339191228634
# Episode score : 1.0
# Mean score : 1.5
# eps_threshold: 0.9373655917225903
# Episode score : 0.0
# Mean score : 1.5
# eps_threshold: 0.937214042266128
# Episode score : 1.0
# Mean score : 1.51
# eps_threshold: 0.9370173200819574
# Episode score : 1.0
# Mean score : 1.52
# eps_threshold: 0.9368449122726346
# Episode score : 0.0
# Mean score : 1.52
# eps_threshold: 0.9366959671347607
# Episode score : 3.0
# Mean score : 1.55
# eps_threshold: 0.9364132116862317
# Episode score : 3.0
# Mean score : 1.56
# eps_threshold: 0.9361481107188505
# Episode score : 1.0
# Mean score : 1.57
# eps_threshold: 0.9359549828124065
# Episode score : 2.0
# Mean score : 1.58
# eps_threshold: 0.9357067410482379
# Episode score : 1.0
# Mean score : 1.56
# eps_threshold: 0.9355346031903901
# Episode score : 3.0
# Mean score : 1.57
# eps_threshold: 0.9352647690941122
# Episode score : 0.0
# Mean score : 1.56
# eps_threshold: 0.9351186105487663
# Episode score : 1.0
# Mean score : 1.56
# eps_threshold: 0.9349474287803347
# Episode score : 3.0
# Mean score : 1.59
# eps_threshold: 0.9346635949090417
# Episode score : 4.0
# Mean score : 1.62
# eps_threshold: 0.9343281275773397
# Episode score : 1.0
# Mean score : 1.62
# eps_threshold: 0.9341312493717735
# Episode score : 2.0
# Mean score : 1.61
# eps_threshold: 0.9338868847168776
# Episode score : 1.0
# Mean score : 1.59
# eps_threshold: 0.9336801064110376
# Episode score : 2.0
# Mean score : 1.61
# eps_threshold: 0.9334467086584528
# Episode score : 3.0
# Mean score : 1.63
# eps_threshold: 0.9331717166207772
# Episode score : 3.0
# Mean score : 1.65
# eps_threshold: 0.9328909850582012
# Episode score : 1.0
# Mean score : 1.65
# eps_threshold: 0.9327052710764118
# Episode score : 1.0
# Mean score : 1.66
# eps_threshold: 0.9325087758197901
# Episode score : 2.0
# Mean score : 1.6
# eps_threshold: 0.9322757059938588
# Episode score : 2.0
# Mean score : 1.62
# eps_threshold: 0.9320493577865803
# Episode score : 2.0
# Mean score : 1.62
# eps_threshold: 0.9318247347854476
# Episode score : 1.0
# Mean score : 1.63
# eps_threshold: 0.9316550598469836
# Episode score : 2.0
# Mean score : 1.62
# eps_threshold: 0.9314205661852669
# Episode score : 2.0
# Mean score : 1.64
# eps_threshold: 0.9312035937336293
# Episode score : 1.0
# Mean score : 1.6
# eps_threshold: 0.9310240731463042
# Episode score : 1.0
# Mean score : 1.57
# eps_threshold: 0.9308271437780204
# Target net updated!
# Episode score : 1.0
# Mean score : 1.58
# eps_threshold: 0.9306285998176058
# Episode score : 0.0
# Mean score : 1.55
# eps_threshold: 0.930475778215258
# Episode score : 2.0
# Mean score : 1.57
# eps_threshold: 0.9302474287757357
# Episode score : 6.0
# Mean score : 1.62
# eps_threshold: 0.9298274298454658
# Episode score : 0.0
# Mean score : 1.6
# eps_threshold: 0.9296789040289807
# Episode score : 3.0
# Mean score : 1.59
# eps_threshold: 0.9293844202920064
# Episode score : 0.0
# Mean score : 1.59
# eps_threshold: 0.9292467539048641
# Episode score : 0.0
# Mean score : 1.59
# eps_threshold: 0.9290983320200702
# Episode score : 0.0
# Mean score : 1.57
# eps_threshold: 0.9289582262412306
# Episode score : 1.0
# Mean score : 1.55
# eps_threshold: 0.928758471380134
# Episode score : 1.0
# Mean score : 1.53
# eps_threshold: 0.9285687074189909
# Episode score : 0.0
# Mean score : 1.52
# eps_threshold: 0.9284320048605379
# Episode score : 0.0
# Mean score : 1.51
# eps_threshold: 0.9282986380440722
# Episode score : 1.0
# Mean score : 1.52
# eps_threshold: 0.9281040107337365
# Episode score : 3.0
# Mean score : 1.55
# eps_threshold: 0.9278200197652902
# Episode score : 3.0
# Mean score : 1.57
# eps_threshold: 0.927534471118445
# Episode score : 0.0
# Mean score : 1.52
# eps_threshold: 0.9273838735494959
# Episode score : 0.0
# Mean score : 1.49
# eps_threshold: 0.9272225494237673
# Episode score : 2.0
# Mean score : 1.48
# eps_threshold: 0.9270099805448363
# Episode score : 1.0
# Mean score : 1.48
# eps_threshold: 0.9268379803575225
# Episode score : 0.0
# Mean score : 1.41
# eps_threshold: 0.9266784160257668
# Episode score : 1.0
# Mean score : 1.42
# eps_threshold: 0.9264800370123545
# Episode score : 1.0
# Mean score : 1.41
# eps_threshold: 0.9263064944271912
# Episode score : 1.0
# Mean score : 1.42
# eps_threshold: 0.9261280314990848
# Episode score : 2.0
# Mean score : 1.44
# eps_threshold: 0.9259132661316029
# Episode score : 2.0
# Mean score : 1.45
# eps_threshold: 0.9256663549800861
# Episode score : 0.0
# Mean score : 1.43
# eps_threshold: 0.9255202249681422
# Episode score : 0.0
# Mean score : 1.4
# eps_threshold: 0.9253757715688139
# Episode score : 0.0
# Mean score : 1.4
# eps_threshold: 0.9252288677563018
# Episode score : 1.0
# Mean score : 1.4
# eps_threshold: 0.9250514626214695
# Episode score : 1.0
# Mean score : 1.4
# eps_threshold: 0.9248806946438024
# Episode score : 2.0
# Mean score : 1.4
# eps_threshold: 0.9246538836407177
# Episode score : 1.0
# Mean score : 1.41
# eps_threshold: 0.9244683573893845
# Episode score : 0.0
# Mean score : 1.41
# eps_threshold: 0.9243232637271008
# Episode score : 0.0
# Mean score : 1.4
# eps_threshold: 0.9241839648666161
# Episode score : 0.0
# Mean score : 1.36
# eps_threshold: 0.9240323289680111
# Episode score : 2.0
# Mean score : 1.36
# eps_threshold: 0.923824698983588
# Episode score : 1.0
# Mean score : 1.34
# eps_threshold: 0.9236583032009332
# Episode score : 6.0
# Mean score : 1.35
# eps_threshold: 0.9233050295714715
# Episode score : 4.0
# Mean score : 1.37
# eps_threshold: 0.9229741274653634
# Episode score : 0.0
# Mean score : 1.37
# eps_threshold: 0.9228301195941132
# Episode score : 1.0
# Mean score : 1.37
# eps_threshold: 0.9226318414287696
# Target net updated!
# Episode score : 1.0
# Mean score : 1.36
# eps_threshold: 0.9224607517996907
# Episode score : 0.0
# Mean score : 1.36
# eps_threshold: 0.9223234123223057
# Episode score : 0.0
# Mean score : 1.35
# eps_threshold: 0.9221729409064052
# Episode score : 2.0
# Mean score : 1.37
# eps_threshold: 0.9219468744332208
# Episode score : 8.0
# Mean score : 1.45
# eps_threshold: 0.9214407110728904
# Episode score : 1.0
# Mean score : 1.45
# eps_threshold: 0.9212665841002542
# Episode score : 1.0
# Mean score : 1.45
# eps_threshold: 0.9210760723529602
# Episode score : 1.0
# Mean score : 1.45
# eps_threshold: 0.9208823212634126
# Episode score : 1.0
# Mean score : 1.43
# eps_threshold: 0.9207173404979611
# Episode score : 1.0
# Mean score : 1.38
# eps_threshold: 0.9205261356338568
# Episode score : 0.0
# Mean score : 1.37
# eps_threshold: 0.9203833765066607
# Episode score : 1.0
# Mean score : 1.37
# eps_threshold: 0.9201930696397613
# Episode score : 0.0
# Mean score : 1.37
# eps_threshold: 0.9200561088336772
# Episode score : 2.0
# Mean score : 1.39
# eps_threshold: 0.919826525266403
# Episode score : 0.0
# Mean score : 1.36
# eps_threshold: 0.9196773304159478
# Episode score : 2.0
# Mean score : 1.37
# eps_threshold: 0.919436380702149
# Episode score : 1.0
# Mean score : 1.38
# eps_threshold: 0.9192421972915656
# Episode score : 3.0
# Mean score : 1.4
# eps_threshold: 0.9189899095491065
# Episode score : 0.0
# Mean score : 1.37
# eps_threshold: 0.918834316248124
# Episode score : 0.0
# Mean score : 1.34
# eps_threshold: 0.9186992197317121
# Episode score : 2.0
# Mean score : 1.36
# eps_threshold: 0.9184520098979169
# Episode score : 4.0
# Mean score : 1.39
# eps_threshold: 0.9181680563192774
# Episode score : 0.0
# Mean score : 1.37
# eps_threshold: 0.9180183452639504
# Episode score : 1.0
# Mean score : 1.35
# eps_threshold: 0.9178498508403475
# Episode score : 1.0
# Mean score : 1.36
# eps_threshold: 0.9176560433927881
# Episode score : 0.0
# Mean score : 1.35
# eps_threshold: 0.917513783618197
# Episode score : 0.0
# Mean score : 1.34
# eps_threshold: 0.9173723659666106
# Episode score : 0.0
# Mean score : 1.33
# eps_threshold: 0.9172260694070353
# Episode score : 0.0
# Mean score : 1.33
# eps_threshold: 0.9170928724135718
# Episode score : 1.0
# Mean score : 1.33
# eps_threshold: 0.9169033288550749
# Episode score : 2.0
# Mean score : 1.34
# eps_threshold: 0.9166836114129338
# Episode score : 1.0
# Mean score : 1.35
# eps_threshold: 0.9164998782711193
# Episode score : 2.0
# Mean score : 1.34
# eps_threshold: 0.9162778205054548
# Episode score : 1.0
# Mean score : 1.32
# eps_threshold: 0.9160778569359684
# Episode score : 1.0
# Mean score : 1.32
# eps_threshold: 0.9158893647227051
# Episode score : 0.0
# Mean score : 1.3
# eps_threshold: 0.9157384391512772
# Episode score : 1.0
# Mean score : 1.3
# eps_threshold: 0.9155435009603617
# Episode score : 1.0
# Mean score : 1.28
# eps_threshold: 0.9153689933241393
# Episode score : 2.0
# Mean score : 1.3
# eps_threshold: 0.9151553946305391
# Episode score : 0.0
# Mean score : 1.29
# eps_threshold: 0.9150119399054703
# Episode score : 3.0
# Mean score : 1.29
# eps_threshold: 0.9147218472944124
# Episode score : 1.0
# Mean score : 1.26
# eps_threshold: 0.9145124906831347
# Target net updated!
# Episode score : 1.0
# Mean score : 1.26
# eps_threshold: 0.9143284316596932
# Episode score : 3.0
# Mean score : 1.27
# eps_threshold: 0.914036954258727
# Episode score : 1.0
# Mean score : 1.27
# eps_threshold: 0.9138326566236338
# Episode score : 0.0
# Mean score : 1.25
# eps_threshold: 0.9136878073027268
# Episode score : 2.0
# Mean score : 1.24
# eps_threshold: 0.9134567527767485
# Episode score : 0.0
# Mean score : 1.21
# eps_threshold: 0.9133087171193967
# Episode score : 3.0
# Mean score : 1.23
# eps_threshold: 0.9130094745755019
# Episode score : 0.0
# Mean score : 1.22
# eps_threshold: 0.912868836101979
# Episode score : 3.0
# Mean score : 1.23
# eps_threshold: 0.9126201362911435
# Episode score : 1.0
# Mean score : 1.22
# eps_threshold: 0.9124446292971422
# Episode score : 3.0
# Mean score : 1.23
# eps_threshold: 0.9121481411198328
# Episode score : 1.0
# Mean score : 1.23
# eps_threshold: 0.91195568481736
# Episode score : 2.0
# Mean score : 1.23
# eps_threshold: 0.9117348629042313
# Episode score : 2.0
# Mean score : 1.23
# eps_threshold: 0.9115400699132283
# Episode score : 0.0
# Mean score : 1.22
# eps_threshold: 0.9113923830604154
# Episode score : 3.0
# Mean score : 1.24
# eps_threshold: 0.9111181787780752
# Episode score : 3.0
# Mean score : 1.26
# eps_threshold: 0.9108164989315002
# Episode score : 0.0
# Mean score : 1.26
# eps_threshold: 0.9106778611640498
# Episode score : 0.0
# Mean score : 1.24
# eps_threshold: 0.9105392471016309
# Episode score : 0.0
# Mean score : 1.18
# eps_threshold: 0.9104038983493004
# Episode score : 0.0
# Mean score : 1.18
# eps_threshold: 0.9102572285177193
# Episode score : 0.0
# Mean score : 1.15
# eps_threshold: 0.9101024841656283
# Episode score : 0.0
# Mean score : 1.15
# eps_threshold: 0.9099591087150328
# Episode score : 3.0
# Mean score : 1.18
# eps_threshold: 0.9097096797235851
# Episode score : 0.0
# Mean score : 1.18
# eps_threshold: 0.909565564227254
# Episode score : 1.0
# Mean score : 1.18
# eps_threshold: 0.9094020484989246
# Episode score : 2.0
# Mean score : 1.19
# eps_threshold: 0.909181921080419
# Episode score : 2.0
# Mean score : 1.21
# eps_threshold: 0.9089594266465088
# Episode score : 3.0
# Mean score : 1.24
# eps_threshold: 0.9087078793824487
# Episode score : 0.0
# Mean score : 1.23
# eps_threshold: 0.908568793588916
# Episode score : 1.0
# Mean score : 1.21
# eps_threshold: 0.9083965867765582
# Episode score : 1.0
# Mean score : 1.19
# eps_threshold: 0.9082349236260567
# Episode score : 2.0
# Mean score : 1.21
# eps_threshold: 0.9080409705196902
# Episode score : 0.0
# Mean score : 1.21
# eps_threshold: 0.9079036152302323
# Episode score : 2.0
# Mean score : 1.21
# eps_threshold: 0.9076790492413171
# Episode score : 0.0
# Mean score : 1.2
# eps_threshold: 0.9075409479318952
# Episode score : 4.0
# Mean score : 1.24
# eps_threshold: 0.9072188033657853
# Episode score : 0.0
# Mean score : 1.23
# eps_threshold: 0.9070670604950293
# Episode score : 2.0
# Mean score : 1.24
# eps_threshold: 0.906844340723075
# Episode score : 1.0
# Mean score : 1.24
# eps_threshold: 0.9066394282855126
# Episode score : 3.0
# Mean score : 1.25
# eps_threshold: 0.9064111816257334
# Target net updated!
# Episode score : 3.0
# Mean score : 1.26
# eps_threshold: 0.9061612329034832
# Episode score : 4.0
# Mean score : 1.3
# eps_threshold: 0.9058404445738997
# Episode score : 2.0
# Mean score : 1.32
# eps_threshold: 0.9055753666753401
# Episode score : 0.0
# Mean score : 1.32
# eps_threshold: 0.9054327924536295
# Episode score : 0.0
# Mean score : 1.31
# eps_threshold: 0.9053007123065352
# Episode score : 2.0
# Mean score : 1.32
# eps_threshold: 0.9050567431538994
# Episode score : 1.0
# Mean score : 1.31
# eps_threshold: 0.9048716013950925
# Episode score : 2.0
# Mean score : 1.32
# eps_threshold: 0.9046519014383202
# Episode score : 0.0
# Mean score : 1.32
# eps_threshold: 0.9045127086998904
# Episode score : 3.0
# Mean score : 1.35
# eps_threshold: 0.9042416335957791
# Episode score : 2.0
# Mean score : 1.37
# eps_threshold: 0.9040036133009762
# Episode score : 1.0
# Mean score : 1.36
# eps_threshold: 0.9038146946506613
# Episode score : 0.0
# Mean score : 1.35
# eps_threshold: 0.9036820761673697
# Episode score : 5.0
# Mean score : 1.34
# eps_threshold: 0.903345403915218
# Episode score : 1.0
# Mean score : 1.31
# eps_threshold: 0.9031502146985169
# Episode score : 0.0
# Mean score : 1.31
# eps_threshold: 0.9030169028280683
# Episode score : 5.0
# Mean score : 1.35
# eps_threshold: 0.902650007945342
# Episode score : 5.0
# Mean score : 1.39
# eps_threshold: 0.9023025357250664
# Episode score : 2.0
# Mean score : 1.41
# eps_threshold: 0.9020466420333838
# Episode score : 0.0
# Mean score : 1.41
# eps_threshold: 0.9019078999658469
# Episode score : 3.0
# Mean score : 1.42
# eps_threshold: 0.9016224715627293
# Episode score : 2.0
# Mean score : 1.36
# eps_threshold: 0.9014044599013943
# Episode score : 2.0
# Mean score : 1.37
# eps_threshold: 0.9011857063450603
# Episode score : 2.0
# Mean score : 1.38
# eps_threshold: 0.9009710173453709
# Episode score : 1.0
# Mean score : 1.38
# eps_threshold: 0.900807635923304
# Episode score : 2.0
# Mean score : 1.39
# eps_threshold: 0.9006042566140452
# Episode score : 1.0
# Mean score : 1.39
# eps_threshold: 0.900436947808792
# Episode score : 3.0
# Mean score : 1.42
# eps_threshold: 0.9001656456717952
# Episode score : 1.0
# Mean score : 1.42
# eps_threshold: 0.8999784288159345
# Episode score : 3.0
# Mean score : 1.45
# eps_threshold: 0.8997224766732403
# Episode score : 0.0
# Mean score : 1.43
# eps_threshold: 0.8995809383213828
# Episode score : 1.0
# Mean score : 1.44
# eps_threshold: 0.8993890619222745
# Episode score : 3.0
# Mean score : 1.45
# eps_threshold: 0.8991181149583881
# Episode score : 2.0
# Mean score : 1.46
# eps_threshold: 0.8989015832906005
# Episode score : 2.0
# Mean score : 1.45
# eps_threshold: 0.8986835129263213
# Episode score : 2.0
# Mean score : 1.47
# eps_threshold: 0.8984663005530273
# Episode score : 3.0
# Mean score : 1.5
# eps_threshold: 0.8982331824301681
# Target net updated!
# Episode score : 2.0
# Mean score : 1.5
# eps_threshold: 0.8980224766843888
# Episode score : 0.0
# Mean score : 1.46
# eps_threshold: 0.8978908138382194
# Episode score : 0.0
# Mean score : 1.46
# eps_threshold: 0.8977575771978775
# Episode score : 1.0
# Mean score : 1.46
# eps_threshold: 0.8975900656959893
# Episode score : 2.0
# Mean score : 1.47
# eps_threshold: 0.8973611901923403
# Episode score : 0.0
# Mean score : 1.47
# eps_threshold: 0.8972216641929378
# Episode score : 0.0
# Mean score : 1.47
# eps_threshold: 0.8970813655266845
# Episode score : 0.0
# Mean score : 1.47
# eps_threshold: 0.8969387007311354
# Episode score : 0.0
# Mean score : 1.47
# eps_threshold: 0.8968024358642885
# Episode score : 2.0
# Mean score : 1.48
# eps_threshold: 0.8965618378607847
# Episode score : 0.0
# Mean score : 1.46
# eps_threshold: 0.8964216553137472
# Episode score : 0.0
# Mean score : 1.45
# eps_threshold: 0.896281497436667
# Episode score : 1.0
# Mean score : 1.44
# eps_threshold: 0.8961111114281687
# Episode score : 0.0
# Mean score : 1.43
# eps_threshold: 0.8959733961186094
# Episode score : 0.0
# Mean score : 1.42
# eps_threshold: 0.895838887980923
# Episode score : 0.0
# Mean score : 1.42
# eps_threshold: 0.8957012197619467
# Episode score : 2.0
# Mean score : 1.43
# eps_threshold: 0.8954625451989926
# Episode score : 3.0
# Mean score : 1.45
# eps_threshold: 0.895200881067732
# Episode score : 0.0
# Mean score : 1.43
# eps_threshold: 0.8950569627332609
# Episode score : 2.0
# Mean score : 1.45
# eps_threshold: 0.8948598130540737
# Episode score : 2.0
# Mean score : 1.44
# eps_threshold: 0.8946277478718274
# Episode score : 6.0
# Mean score : 1.49
# eps_threshold: 0.8942345044724018
# Episode score : 2.0
# Mean score : 1.5
# eps_threshold: 0.8940248542382696
# Episode score : 0.0
# Mean score : 1.47
# eps_threshold: 0.8938978204245676
# Episode score : 2.0
# Mean score : 1.48
# eps_threshold: 0.8936612741212308
# Episode score : 3.0
# Mean score : 1.51
# eps_threshold: 0.8933843346653084
# Episode score : 1.0
# Mean score : 1.5
# eps_threshold: 0.8932113957313801
# Episode score : 2.0
# Mean score : 1.52
# eps_threshold: 0.8929909136118014
# Episode score : 5.0
# Mean score : 1.54
# eps_threshold: 0.8926333553452122
# Episode score : 5.0
# Mean score : 1.59
# eps_threshold: 0.8922680355810736
# Episode score : 0.0
# Mean score : 1.56
# eps_threshold: 0.8921167268367227
# Episode score : 2.0
# Mean score : 1.57
# eps_threshold: 0.8919084275301241
# Episode score : 3.0
# Mean score : 1.57
# eps_threshold: 0.8916431826379015
# Episode score : 4.0
# Mean score : 1.6
# eps_threshold: 0.8913408326946497
# Episode score : 0.0
# Mean score : 1.58
# eps_threshold: 0.8912031513683836
# Episode score : 1.0
# Mean score : 1.57
# eps_threshold: 0.8910204045484877
# Episode score : 4.0
# Mean score : 1.61
# eps_threshold: 0.890709594607654
# Episode score : 1.0
# Mean score : 1.59
# eps_threshold: 0.8905245902088746
# Episode score : 0.0
# Mean score : 1.56
# eps_threshold: 0.890388631672128
# Target net updated!
# Episode score : 3.0
# Mean score : 1.59
# eps_threshold: 0.8901041429757639
# Episode score : 4.0
# Mean score : 1.63
# eps_threshold: 0.8897826360206762
# Episode score : 1.0
# Mean score : 1.64
# eps_threshold: 0.8895962693107121
# Episode score : 1.0
# Mean score : 1.65
# eps_threshold: 0.8894083677597876
# Episode score : 1.0
# Mean score : 1.66
# eps_threshold: 0.8892205109241111
# Episode score : 0.0
# Mean score : 1.66
# eps_threshold: 0.8890500577033621
# Episode score : 0.0
# Mean score : 1.63
# eps_threshold: 0.8889001524338499
# Episode score : 0.0
# Mean score : 1.63
# eps_threshold: 0.8887699946470111
# Episode score : 0.0
# Mean score : 1.62
# eps_threshold: 0.8886256629447442
# Episode score : 1.0
# Mean score : 1.61
# eps_threshold: 0.8884340501905411
# Episode score : 0.0
# Mean score : 1.59
# eps_threshold: 0.8882976628976992
# Episode score : 2.0
# Mean score : 1.58
# eps_threshold: 0.8880643613198184
# Episode score : 3.0
# Mean score : 1.61
# eps_threshold: 0.8877885870566676
# Episode score : 2.0
# Mean score : 1.62
# eps_threshold: 0.8875688246991533
# Episode score : 0.0
# Mean score : 1.61
# eps_threshold: 0.8874404614426169
# Episode score : 0.0
# Mean score : 1.59
# eps_threshold: 0.8873097571747718
# Episode score : 0.0
# Mean score : 1.59
# eps_threshold: 0.8871775002454596
# Episode score : 2.0
# Mean score : 1.59
# eps_threshold: 0.8869649910104311
# Episode score : 0.0
# Mean score : 1.59
# eps_threshold: 0.8868320051645708
# Episode score : 0.0
# Mean score : 1.55
# eps_threshold: 0.8866951083060443
# Episode score : 1.0
# Mean score : 1.56
# eps_threshold: 0.8865322792720114
# Episode score : 4.0
# Mean score : 1.58
# eps_threshold: 0.8862067223033352
# Episode score : 2.0
# Mean score : 1.59
# eps_threshold: 0.8859999771235523
# Episode score : 0.0
# Mean score : 1.56
# eps_threshold: 0.8858600815786971
# Episode score : 4.0
# Mean score : 1.57
# eps_threshold: 0.8855575836818709
# Episode score : 0.0
# Mean score : 1.53
# eps_threshold: 0.8854036294834736
# Episode score : 2.0
# Mean score : 1.53
# eps_threshold: 0.8851594069332792
# Episode score : 2.0
# Mean score : 1.55
# eps_threshold: 0.8849552920235646
# Episode score : 0.0
# Mean score : 1.55
# eps_threshold: 0.8848187216847166
# Episode score : 0.0
# Mean score : 1.53
# eps_threshold: 0.8846821751070403
# Episode score : 1.0
# Mean score : 1.53
# eps_threshold: 0.8845017189600181
# Episode score : 3.0
# Mean score : 1.54
# eps_threshold: 0.8842334652461334
# Episode score : 0.0
# Mean score : 1.54
# eps_threshold: 0.8840970204942183
# Episode score : 0.0
# Mean score : 1.51
# eps_threshold: 0.8839668711915073
# Episode score : 0.0
# Mean score : 1.49
# eps_threshold: 0.8838328243178678
# Episode score : 3.0
# Mean score : 1.51
# eps_threshold: 0.8835961425456703
# Episode score : 2.0
# Mean score : 1.53
# eps_threshold: 0.8833853835316838
# Episode score : 0.0
# Mean score : 1.48
# eps_threshold: 0.8832514360839331
# Episode score : 0.0
# Mean score : 1.47
# eps_threshold: 0.8831104635133499
# Episode score : 0.0
# Mean score : 1.47
# eps_threshold: 0.8829883078094345
# Episode score : 1.0
# Mean score : 1.43
# eps_threshold: 0.8828082412070914
# Episode score : 2.0
# Mean score : 1.4
# eps_threshold: 0.882585955232691
# Target net updated!
# Episode score : 7.0
# Mean score : 1.45
# eps_threshold: 0.8821869381535262
# Episode score : 0.0
# Mean score : 1.45
# eps_threshold: 0.8820438110403743
# Episode score : 0.0
# Mean score : 1.42
# eps_threshold: 0.8819124387157038
# Episode score : 8.0
# Mean score : 1.48
# eps_threshold: 0.8814496835410308
# Episode score : 0.0
# Mean score : 1.46
# eps_threshold: 0.8813059100268281
# Episode score : 0.0
# Mean score : 1.44
# eps_threshold: 0.8811707557955716
# Episode score : 1.0
# Mean score : 1.44
# eps_threshold: 0.8809786114243726
# Episode score : 2.0
# Mean score : 1.44
# eps_threshold: 0.8807638718342778
# Episode score : 2.0
# Mean score : 1.45
# eps_threshold: 0.8805476301926298
# Episode score : 1.0
# Mean score : 1.43
# eps_threshold: 0.8803587605202752
# Episode score : 0.0
# Mean score : 1.42
# eps_threshold: 0.8802323526403857
# Episode score : 0.0
# Mean score : 1.39
# eps_threshold: 0.880098944314821
# Episode score : 0.0
# Mean score : 1.39
# eps_threshold: 0.8799639988705721
# Episode score : 1.0
# Mean score : 1.39
# eps_threshold: 0.8797854075643158
# Episode score : 1.0
# Mean score : 1.37
# eps_threshold: 0.8796099755844516
# Episode score : 0.0
# Mean score : 1.35
# eps_threshold: 0.8794813505503374
# Episode score : 2.0
# Mean score : 1.35
# eps_threshold: 0.8792911803025167
# Episode score : 1.0
# Mean score : 1.34
# eps_threshold: 0.8791181968623619
# Episode score : 1.0
# Mean score : 1.32
# eps_threshold: 0.8789242205823923
# Episode score : 2.0
# Mean score : 1.32
# eps_threshold: 0.8787014801087117
# Episode score : 1.0
# Mean score : 1.33
# eps_threshold: 0.8785083860862932
# Episode score : 2.0
# Mean score : 1.35
# eps_threshold: 0.8782904342528697
# Episode score : 0.0
# Mean score : 1.34
# eps_threshold: 0.8781589142832313
# Episode score : 0.0
# Mean score : 1.32
# eps_threshold: 0.878017302247918
# Episode score : 2.0
# Mean score : 1.34
# eps_threshold: 0.8778018213006843
# Episode score : 0.0
# Mean score : 1.34
# eps_threshold: 0.8776649402260233
# Episode score : 0.0
# Mean score : 1.34
# eps_threshold: 0.8775226405627783
# Episode score : 2.0
# Mean score : 1.36
# eps_threshold: 0.8772971916886818
# Episode score : 1.0
# Mean score : 1.35
# eps_threshold: 0.877106777203445
# Episode score : 0.0
# Mean score : 1.35
# eps_threshold: 0.8769707954161877
# Episode score : 1.0
# Mean score : 1.36
# eps_threshold: 0.8768006574427798
# Episode score : 0.0
# Mean score : 1.35
# eps_threshold: 0.8766709425644805
# Episode score : 0.0
# Mean score : 1.35
# eps_threshold: 0.8765342605069631
# Episode score : 1.0
# Mean score : 1.36
# eps_threshold: 0.8763766400510978
# Episode score : 3.0
# Mean score : 1.39
# eps_threshold: 0.876111940750636
# Episode score : 0.0
# Mean score : 1.37
# eps_threshold: 0.8759738051196183
# Episode score : 2.0
# Mean score : 1.36
# eps_threshold: 0.8757565628695192
# Episode score : 0.0
# Mean score : 1.36
# eps_threshold: 0.8756246954628785
# Episode score : 0.0
# Mean score : 1.34
# eps_threshold: 0.8754936259650298
# Episode score : 1.0
# Mean score : 1.33
# eps_threshold: 0.8753160582569623
# Episode score : 0.0
# Mean score : 1.27
# eps_threshold: 0.8751811649988794
# Episode score : 6.0
# Mean score : 1.31
# eps_threshold: 0.8749401211408275
# Episode score : 0.0
# Mean score : 1.31
# eps_threshold: 0.8748014192733308
# Target net updated!
# Episode score : 3.0
# Mean score : 1.32
# eps_threshold: 0.8745395806468371
# Episode score : 2.0
# Mean score : 1.31
# eps_threshold: 0.8743304831894895
# Episode score : 0.0
# Mean score : 1.3
# eps_threshold: 0.8742027291997572
# Episode score : 0.0
# Mean score : 1.28
# eps_threshold: 0.8740688037124943
# Episode score : 4.0
# Mean score : 1.27
# eps_threshold: 0.8737809036702412
# Episode score : 0.0
# Mean score : 1.22
# eps_threshold: 0.8736578822870168
# Episode score : 1.0
# Mean score : 1.23
# eps_threshold: 0.8734745470949932
# Episode score : 0.0
# Mean score : 1.21
# eps_threshold: 0.873336880878267
# Episode score : 2.0
# Mean score : 1.2
# eps_threshold: 0.8731103263640267
# Episode score : 3.0
# Mean score : 1.19
# eps_threshold: 0.8728567877595835
# Episode score : 1.0
# Mean score : 1.2
# eps_threshold: 0.872666688372978
# Episode score : 1.0
# Mean score : 1.2
# eps_threshold: 0.87250676292134
# Episode score : 0.0
# Mean score : 1.16
# eps_threshold: 0.872377765063553
# Episode score : 3.0
# Mean score : 1.18
# eps_threshold: 0.8721422257667774
# Episode score : 0.0
# Mean score : 1.18
# eps_threshold: 0.8719993926674796
# Episode score : 2.0
# Mean score : 1.17
# eps_threshold: 0.8717693711233769
# Episode score : 1.0
# Mean score : 1.14
# eps_threshold: 0.8715880266299755
# Episode score : 2.0
# Mean score : 1.15
# eps_threshold: 0.8713758690956503
# Episode score : 4.0
# Mean score : 1.18
# eps_threshold: 0.8710835730348653
# Episode score : 2.0
# Mean score : 1.19
# eps_threshold: 0.8708584495011746
# Episode score : 0.0
# Mean score : 1.19
# eps_threshold: 0.8707073760507542
# Episode score : 0.0
# Mean score : 1.19
# eps_threshold: 0.8705725140607136
# Episode score : 2.0
# Mean score : 1.21
# eps_threshold: 0.8703660282972736
# Episode score : 1.0
# Mean score : 1.22
# eps_threshold: 0.8701957962163577
# Episode score : 2.0
# Mean score : 1.23
# eps_threshold: 0.8699616922799092
# Episode score : 0.0
# Mean score : 1.23
# eps_threshold: 0.8698315797487324
# Episode score : 1.0
# Mean score : 1.22
# eps_threshold: 0.8696499209324953
# Episode score : 0.0
# Mean score : 1.19
# eps_threshold: 0.8695121659260892
# Episode score : 1.0
# Mean score : 1.18
# eps_threshold: 0.8693321211453233
# Episode score : 1.0
# Mean score : 1.19
# eps_threshold: 0.8691544259499241
# Episode score : 1.0
# Mean score : 1.2
# eps_threshold: 0.8689783097524557
# Episode score : 3.0
# Mean score : 1.23
# eps_threshold: 0.8687199764428053
# Episode score : 4.0
# Mean score : 1.25
# eps_threshold: 0.8684140867682641
# Episode score : 1.0
# Mean score : 1.26
# eps_threshold: 0.8682512002484504
# Episode score : 0.0
# Mean score : 1.26
# eps_threshold: 0.8681175361687193
# Episode score : 1.0
# Mean score : 1.26
# eps_threshold: 0.8679362818190381
# Episode score : 4.0
# Mean score : 1.26
# eps_threshold: 0.8676015345803659
# Episode score : 0.0
# Mean score : 1.24
# eps_threshold: 0.8674664485981949
# Episode score : 1.0
# Mean score : 1.25
# eps_threshold: 0.8673068321775697
# Episode score : 1.0
# Mean score : 1.22
# eps_threshold: 0.8671380432419543
# Episode score : 0.0
# Mean score : 1.22
# eps_threshold: 0.8670137769447909
# Target net updated!
# Episode score : 0.0
# Mean score : 1.2
# eps_threshold: 0.8668826288024192
# Episode score : 0.0
# Mean score : 1.18
# eps_threshold: 0.8667392351585566
# Episode score : 1.0
# Mean score : 1.19
# eps_threshold: 0.86658130314367
# Episode score : 0.0
# Mean score : 1.19
# eps_threshold: 0.8664417980418472
# Episode score : 2.0
# Mean score : 1.2
# eps_threshold: 0.8662226270305557
# Episode score : 1.0
# Mean score : 1.18
# eps_threshold: 0.866033393412993
# Episode score : 0.0
# Mean score : 1.18
# eps_threshold: 0.86590394470823
# Episode score : 1.0
# Mean score : 1.19
# eps_threshold: 0.8657331671709632
# Episode score : 2.0
# Mean score : 1.21
# eps_threshold: 0.865508074710028
# Episode score : 0.0
# Mean score : 1.18
# eps_threshold: 0.865371826399189
# Episode score : 0.0
# Mean score : 1.16
# eps_threshold: 0.8652424894898042
# Episode score : 0.0
# Mean score : 1.16
# eps_threshold: 0.8651047582378806
# Episode score : 1.0
# Mean score : 1.17
# eps_threshold: 0.8649349238338682
# Episode score : 0.0
# Mean score : 1.17
# eps_threshold: 0.8648003071338904
# ...
# Episode score : 15.0
# Mean score : 30.96
# eps_threshold: 0.14966710105556535
# Episode score : 37.0
# Mean score : 31.01
# eps_threshold: 0.14959513594634782
# Episode score : 38.0
# Mean score : 30.89
# eps_threshold: 0.14953060509804403
# Target net updated!
# Episode score : 44.0
# Mean score : 31.09
# eps_threshold: 0.1494573540216662
# Episode score : 39.0
# Mean score : 31.31
# eps_threshold: 0.14940051075568384
# Episode score : 32.0
# Mean score : 31.31
# eps_threshold: 0.14933899605090187
# Episode score : 32.0
# Mean score : 31.4
# eps_threshold: 0.14927898701561246
# Episode score : 41.0
# Mean score : 31.7
# eps_threshold: 0.1491955298825225
# Episode score : 55.0
# Mean score : 32.01
# eps_threshold: 0.1491170273222789
# Episode score : 17.0
# Mean score : 32.01
# eps_threshold: 0.14907740587063587
# Target net updated!
# Episode score : 33.0
# Mean score : 32.16
# eps_threshold: 0.1490168326860261
# Episode score : 13.0
# Mean score : 32.16
# eps_threshold: 0.14897812467987973
# Episode score : 34.0
# Mean score : 32.15
# eps_threshold: 0.14891014129009372
# Episode score : 21.0
# Mean score : 31.98
# eps_threshold: 0.14886096242907054
# Episode score : 47.0
# Mean score : 32.12
# eps_threshold: 0.14878509146046687
# Episode score : 24.0
# Mean score : 31.95
# eps_threshold: 0.14874437291145742
# Episode score : 26.0
# Mean score : 31.98
# eps_threshold: 0.14868664504007637
# Episode score : 16.0
# Mean score : 32.03
# eps_threshold: 0.14864245763049985
# Episode score : 56.0
# Mean score : 32.06
# eps_threshold: 0.1485628950670843
# Target net updated!
# Episode score : 57.0
# Mean score : 32.41
# eps_threshold: 0.14848026283809895
# Episode score : 47.0
# Mean score : 32.64
# eps_threshold: 0.1483980615995406
# Episode score : 33.0
# Mean score : 32.28
# eps_threshold: 0.14832721035050908
# Episode score : 37.0
# Mean score : 32.48
# eps_threshold: 0.1482727279910613
# Episode score : 18.0
# Mean score : 32.62
# eps_threshold: 0.14823045959760045
# Episode score : 13.0
# Mean score : 32.38
# eps_threshold: 0.14819420392582422
# Episode score : 40.0
# Mean score : 32.42
# eps_threshold: 0.14812413234854654
# Episode score : 32.0
# Mean score : 32.52
# eps_threshold: 0.1480634860631742
# Target net updated!
# Episode score : 16.0
# Mean score : 32.29
# eps_threshold: 0.1480259151092304
# Episode score : 16.0
# Mean score : 32.17
# eps_threshold: 0.14798021619418142
# Episode score : 21.0
# Mean score : 32.08
# eps_threshold: 0.14793388968464444
# Episode score : 28.0
# Mean score : 32.04
# eps_threshold: 0.14788052106337699
# Episode score : 43.0
# Mean score : 32.22
# eps_threshold: 0.1478076067241153
# Episode score : 17.0
# Mean score : 31.96
# eps_threshold: 0.1477702357895969
# Episode score : 36.0
# Mean score : 32.0
# eps_threshold: 0.14771423415439594
# Episode score : 27.0
# Mean score : 32.04
# eps_threshold: 0.14765167412753694
# Target net updated!
# Episode score : 67.0
# Mean score : 32.41
# eps_threshold: 0.147563219516788
# Episode score : 21.0
# Mean score : 32.37
# eps_threshold: 0.1475246138585588
# Episode score : 48.0
# Mean score : 32.47
# eps_threshold: 0.14744317899614576
# Episode score : 20.0
# Mean score : 32.28
# eps_threshold: 0.14739803458189216
# Episode score : 34.0
# Mean score : 32.36
# eps_threshold: 0.14733106112238809
# Episode score : 19.0
# Mean score : 32.28
# eps_threshold: 0.14729174534856193
# Episode score : 38.0
# Mean score : 32.47
# eps_threshold: 0.14722643329751256
# Episode score : 56.0
# Mean score : 32.86
# eps_threshold: 0.14715286464966335
# Target net updated!
# Episode score : 30.0
# Mean score : 32.79
# eps_threshold: 0.14708986339535018
# Episode score : 21.0
# Mean score : 32.77
# eps_threshold: 0.1470429852406048
# Episode score : 27.0
# Mean score : 32.86
# eps_threshold: 0.14698464110594467
# Episode score : 11.0
# Mean score : 32.66
# eps_threshold: 0.14695087129069287
# Episode score : 62.0
# Mean score : 32.92
# eps_threshold: 0.14686081210230179
# Episode score : 27.0
# Mean score : 32.82
# eps_threshold: 0.1468063446567856
# Episode score : 29.0
# Mean score : 32.88
# eps_threshold: 0.14675988902557963
# Episode score : 58.0
# Mean score : 32.98
# eps_threshold: 0.14668709384065184
# Target net updated!
# Episode score : 49.0
# Mean score : 33.14
# eps_threshold: 0.14661264066831772
# Episode score : 28.0
# Mean score : 33.1
# eps_threshold: 0.1465605568563265
# Episode score : 37.0
# Mean score : 33.23
# eps_threshold: 0.14649523170348835
# Episode score : 38.0
# Mean score : 33.41
# eps_threshold: 0.1464248447590308
# Episode score : 60.0
# Mean score : 33.52
# eps_threshold: 0.14633658228783192
# Episode score : 55.0
# Mean score : 33.69
# eps_threshold: 0.1462582470808746
# Episode score : 25.0
# Mean score : 33.69
# eps_threshold: 0.14619833522392683
# Target net updated!
# Episode score : 26.0
# Mean score : 33.5
# eps_threshold: 0.1461504523818442
# Episode score : 17.0
# Mean score : 33.44
# eps_threshold: 0.14611723601545612
# Episode score : 31.0
# Mean score : 33.54
# eps_threshold: 0.14606275764554524
# Episode score : 25.0
# Mean score : 33.51
# eps_threshold: 0.14600696340142066
# Episode score : 36.0
# Mean score : 33.75
# eps_threshold: 0.14593579971697782
# Episode score : 58.0
# Mean score : 34.04
# eps_threshold: 0.14584814607539356
# Episode score : 41.0
# Mean score : 34.08
# eps_threshold: 0.14578551447815846
# Episode score : 33.0
# Mean score : 33.89
# eps_threshold: 0.14572630633835185
# Target net updated!
# Episode score : 26.0
# Mean score : 33.83
# eps_threshold: 0.14566854480012278
# Episode score : 30.0
# Mean score : 33.98
# eps_threshold: 0.145612680697093
# Episode score : 30.0
# Mean score : 34.11
# eps_threshold: 0.14556030182439697
# Episode score : 42.0
# Mean score : 33.97
# eps_threshold: 0.1454797314160141
# Episode score : 27.0
# Mean score : 33.7
# eps_threshold: 0.1454221905071221
# Episode score : 59.0
# Mean score : 33.95
# eps_threshold: 0.14533542625193277
# Episode score : 16.0
# Mean score : 33.81
# eps_threshold: 0.1452938727212654
# Target net updated!
# Episode score : 38.0
# Mean score : 33.95
# eps_threshold: 0.14522770146232364
# Episode score : 37.0
# Mean score : 33.93
# eps_threshold: 0.14516185268377713
# Episode score : 42.0
# Mean score : 33.94
# eps_threshold: 0.14510029390934476
# Episode score : 16.0
# Mean score : 33.89
# eps_threshold: 0.145059586726004
# Episode score : 32.0
# Mean score : 33.81
# eps_threshold: 0.14501175884600043
# Episode score : 26.0
# Mean score : 33.44
# eps_threshold: 0.14495561920938038
# Episode score : 23.0
# Mean score : 33.51
# eps_threshold: 0.14491064114982624
# Episode score : 82.0
# Mean score : 33.91
# eps_threshold: 0.1448277677527643
# Target net updated!
# Episode score : 28.0
# Mean score : 33.92
# eps_threshold: 0.14477454398585132
# Episode score : 49.0
# Mean score : 33.86
# eps_threshold: 0.1446988048141827
# Episode score : 78.0
# Mean score : 34.34
# eps_threshold: 0.14461172707318526
# Episode score : 39.0
# Mean score : 34.53
# eps_threshold: 0.14454450328823204
# Episode score : 22.0
# Mean score : 34.21
# eps_threshold: 0.14449517531133438
# Episode score : 15.0
# Mean score : 33.93
# eps_threshold: 0.14445665916941133
# Episode score : 42.0
# Mean score : 34.07
# eps_threshold: 0.1443885593227738
# Target net updated!
# Episode score : 28.0
# Mean score : 34.07
# eps_threshold: 0.14433612304160146
# Episode score : 20.0
# Mean score : 33.81
# eps_threshold: 0.14429752309115093
# Episode score : 35.0
# Mean score : 33.83
# eps_threshold: 0.14424147791100211
# Episode score : 36.0
# Mean score : 33.68
# eps_threshold: 0.14418722690740243
# Episode score : 30.0
# Mean score : 33.78
# eps_threshold: 0.1441258493293002
# Episode score : 33.0
# Mean score : 33.91
# eps_threshold: 0.14406936030525397
# Episode score : 25.0
# Mean score : 34.03
# eps_threshold: 0.14402121880856095
# Episode score : 14.0
# Mean score : 33.97
# eps_threshold: 0.14398588395869857
# Target net updated!
# Episode score : 34.0
# Mean score : 33.85
# eps_threshold: 0.1439196032339159
# Episode score : 30.0
# Mean score : 33.98
# eps_threshold: 0.14386223780896057
# Episode score : 61.0
# Mean score : 34.0
# eps_threshold: 0.1437907130169617
# Episode score : 39.0
# Mean score : 34.12
# eps_threshold: 0.1437304547025083
# Episode score : 35.0
# Mean score : 34.32
# eps_threshold: 0.14367289960201785
# Episode score : 24.0
# Mean score : 34.19
# eps_threshold: 0.1436276779069129
# Episode score : 32.0
# Mean score : 34.13
# eps_threshold: 0.14357823216120302
# Episode score : 23.0
# Mean score : 33.92
# eps_threshold: 0.14353855046945913
# Episode score : 29.0
# Mean score : 33.82
# eps_threshold: 0.1434897276105781
# Target net updated!
# Episode score : 24.0
# Mean score : 33.74
# eps_threshold: 0.14344187176995338
# Episode score : 21.0
# Mean score : 33.63
# eps_threshold: 0.14339259321636377
# Episode score : 12.0
# Mean score : 33.34
# eps_threshold: 0.143361188348809
# Episode score : 38.0
# Mean score : 33.17
# eps_threshold: 0.14330836326364255
# Episode score : 28.0
# Mean score : 33.28
# eps_threshold: 0.1432578086250069
# Episode score : 64.0
# Mean score : 33.59
# eps_threshold: 0.1431742720450504
# Episode score : 47.0
# Mean score : 33.93
# eps_threshold: 0.14309408562968462
# Target net updated!
# Episode score : 40.0
# Mean score : 33.99
# eps_threshold: 0.14303151539155093
# Episode score : 18.0
# Mean score : 33.96
# eps_threshold: 0.14298601212373993
# Episode score : 35.0
# Mean score : 33.84
# eps_threshold: 0.1429373794892802
# Episode score : 40.0
# Mean score : 34.0
# eps_threshold: 0.14287589428913955
# Episode score : 45.0
# Mean score : 34.19
# eps_threshold: 0.14281227083822448
# Episode score : 30.0
# Mean score : 34.33
# eps_threshold: 0.1427545132677249
# Episode score : 54.0
# Mean score : 34.31
# eps_threshold: 0.14268146552365818
# Episode score : 28.0
# Mean score : 34.02
# eps_threshold: 0.1426391038644379
# Target net updated!
# Episode score : 18.0
# Mean score : 33.73
# eps_threshold: 0.142605261853026
# Episode score : 35.0
# Mean score : 33.75
# eps_threshold: 0.14254769846062232
# Episode score : 26.0
# Mean score : 33.64
# eps_threshold: 0.14249841424382698
# Episode score : 33.0
# Mean score : 33.79
# eps_threshold: 0.14244256555765542
# Episode score : 28.0
# Mean score : 33.94
# eps_threshold: 0.14239395423713316
# Episode score : 24.0
# Mean score : 33.78
# eps_threshold: 0.1423532755699499
# Episode score : 32.0
# Mean score : 33.78
# eps_threshold: 0.1422889474928075
# Episode score : 28.0
# Mean score : 33.9
# eps_threshold: 0.14224220177202912
# Target net updated!
# Episode score : 31.0
# Mean score : 34.05
# eps_threshold: 0.14218546638756613
# Episode score : 25.0
# Mean score : 34.09
# eps_threshold: 0.14214224843750212
# Episode score : 5.0
# Mean score : 33.86
# eps_threshold: 0.1421251000323252
# Episode score : 24.0
# Mean score : 33.67
# eps_threshold: 0.14208286973902523
# Episode score : 54.0
# Mean score : 34.04
# eps_threshold: 0.14200685265069238
# Episode score : 51.0
# Mean score : 34.19
# eps_threshold: 0.14194003094546292
# Episode score : 28.0
# Mean score : 34.2
# eps_threshold: 0.1418939222758405
# Episode score : 12.0
# Mean score : 33.65
# eps_threshold: 0.1418638950995978
# Episode score : 37.0
# Mean score : 33.81
# eps_threshold: 0.14180846217101598
# Target net updated!
# Episode score : 29.0
# Mean score : 33.62
# eps_threshold: 0.14175627599881313
# Episode score : 27.0
# Mean score : 33.69
# eps_threshold: 0.14170836729882189
# Episode score : 23.0
# Mean score : 33.58
# eps_threshold: 0.14166288828341284
# Episode score : 28.0
# Mean score : 33.67
# eps_threshold: 0.14161708430310882
# Episode score : 23.0
# Mean score : 33.52
# eps_threshold: 0.14156767256334155
# Episode score : 48.0
# Mean score : 33.44
# eps_threshold: 0.14149868596844162
# Episode score : 21.0
# Mean score : 33.35
# eps_threshold: 0.141457954261362
# Episode score : 26.0
# Mean score : 33.4
# eps_threshold: 0.1414064954447094
# Target net updated!
# Episode score : 36.0
# Mean score : 33.49
# eps_threshold: 0.14135472830600465
# Episode score : 47.0
# Mean score : 33.85
# eps_threshold: 0.14129171040869767
# Episode score : 36.0
# Mean score : 33.59
# eps_threshold: 0.14123307655742456
# Episode score : 19.0
# Mean score : 33.51
# eps_threshold: 0.14119075192521882
# Episode score : 26.0
# Mean score : 33.48
# eps_threshold: 0.14114246349990875
# Episode score : 32.0
# Mean score : 33.22
# eps_threshold: 0.14109114973191222
# Episode score : 35.0
# Mean score : 33.08
# eps_threshold: 0.14103579617875037
# Episode score : 37.0
# Mean score : 33.17
# eps_threshold: 0.1409816236808109
# Target net updated!
# Episode score : 16.0
# Mean score : 32.96
# eps_threshold: 0.1409505304298186
# Episode score : 101.0
# Mean score : 33.59
# eps_threshold: 0.1408548590704156
# Episode score : 26.0
# Mean score : 33.25
# eps_threshold: 0.14080361838253933
# Episode score : 28.0
# Mean score : 32.98
# eps_threshold: 0.14075313475879264
# Episode score : 46.0
# Mean score : 33.19
# eps_threshold: 0.14069314958122217
# Episode score : 53.0
# Mean score : 33.46
# eps_threshold: 0.14062155200497825
# Episode score : 34.0
# Mean score : 33.63
# eps_threshold: 0.14056082759636163
# Target net updated!
# Episode score : 28.0
# Mean score : 33.6
# eps_threshold: 0.14052081380957615
# Episode score : 38.0
# Mean score : 33.73
# eps_threshold: 0.14045247237226605
# Episode score : 18.0
# Mean score : 33.55
# eps_threshold: 0.1404165665213567
# Episode score : 39.0
# Mean score : 33.36
# eps_threshold: 0.1403739091541641
# Episode score : 67.0
# Mean score : 33.62
# eps_threshold: 0.14029864168606998
# Episode score : 53.0
# Mean score : 33.82
# eps_threshold: 0.14023156004354495
# Episode score : 26.0
# Mean score : 33.82
# eps_threshold: 0.14017820817016424
# Target net updated!
# Episode score : 64.0
# Mean score : 34.16
# eps_threshold: 0.14010663425210643
# Episode score : 39.0
# Mean score : 34.25
# eps_threshold: 0.14005156557748707
# Episode score : 29.0
# Mean score : 34.12
# eps_threshold: 0.13999725246278133
# Episode score : 57.0
# Mean score : 34.42
# eps_threshold: 0.1399299937010103
# Episode score : 53.0
# Mean score : 34.36
# eps_threshold: 0.1398709808910567
# Episode score : 19.0
# Mean score : 34.39
# eps_threshold: 0.13983475463675374
# Episode score : 25.0
# Mean score : 34.26
# eps_threshold: 0.13978650415982946
# Target net updated!
# Episode score : 46.0
# Mean score : 34.35
# eps_threshold: 0.13973131879955542
# Episode score : 15.0
# Mean score : 34.08
# eps_threshold: 0.139700777160164
# Episode score : 25.0
# Mean score : 34.17
# eps_threshold: 0.13966105656570085
# Episode score : 10.0
# Mean score : 33.95
# eps_threshold: 0.13963706888348415
# Episode score : 48.0
# Mean score : 34.17
# eps_threshold: 0.13957678715067895
# Episode score : 26.0
# Mean score : 34.2
# eps_threshold: 0.13952371072457037
# Episode score : 51.0
# Mean score : 33.89
# eps_threshold: 0.1394516851834712
# Episode score : 23.0
# Mean score : 33.84
# eps_threshold: 0.13940732699379987
# Episode score : 36.0
# Mean score : 33.71
# eps_threshold: 0.13936042080553002
# Target net updated!
# Episode score : 24.0
# Mean score : 33.17
# eps_threshold: 0.13931474987408055
# Episode score : 22.0
# Mean score : 33.0
# eps_threshold: 0.1392699173263066
# Episode score : 22.0
# Mean score : 33.0
# eps_threshold: 0.13923451183115712
# Episode score : 33.0
# Mean score : 33.18
# eps_threshold: 0.13917938686945167
# Episode score : 52.0
# Mean score : 33.28
# eps_threshold: 0.13911588941430675
# Episode score : 38.0
# Mean score : 33.38
# eps_threshold: 0.13905850941587
# Episode score : 36.0
# Mean score : 33.54
# eps_threshold: 0.13900429480705362
# Target net updated!
# Episode score : 52.0
# Mean score : 33.71
# eps_threshold: 0.1389368757113701
# Episode score : 35.0
# Mean score : 33.7
# eps_threshold: 0.13888547405682303
# Episode score : 47.0
# Mean score : 33.87
# eps_threshold: 0.13882136592837976
# Episode score : 33.0
# Mean score : 33.87
# eps_threshold: 0.13876038668338447
# Episode score : 25.0
# Mean score : 33.87
# eps_threshold: 0.13871312784538362
# Episode score : 39.0
# Mean score : 34.12
# eps_threshold: 0.13864887871370782
# Episode score : 37.0
# Mean score : 34.15
# eps_threshold: 0.13859438360118595
# Target net updated!
# Episode score : 27.0
# Mean score : 34.12
# eps_threshold: 0.13854424350063116
# Episode score : 35.0
# Mean score : 33.86
# eps_threshold: 0.13849205141880871
# Episode score : 43.0
# Mean score : 33.9
# eps_threshold: 0.13843697024870735
# Episode score : 43.0
# Mean score : 33.98
# eps_threshold: 0.13837509814100094
# Episode score : 56.0
# Mean score : 34.3
# eps_threshold: 0.13831018406511844
# Episode score : 29.0
# Mean score : 34.27
# eps_threshold: 0.13827376839846656
# Episode score : 35.0
# Mean score : 34.39
# eps_threshold: 0.13822366258833574
# Episode score : 21.0
# Mean score : 34.31
# eps_threshold: 0.1381869091061851
# Target net updated!
# Episode score : 74.0
# Mean score : 34.81
# eps_threshold: 0.1381162142825936
# Episode score : 44.0
# Mean score : 35.04
# eps_threshold: 0.13806212766889642

# %%
# Тут код для тестирования.
print(eps_threshold)

TEST_EPS = 0.05

def show_state(env, step=0, info=""):
    plt.figure(3)
    plt.clf()
    plt.imshow(env.render(mode='rgb_array'))
    plt.title("%s | Step: %d %s" % (env.spec.id, step, info))
    plt.axis('off')

    display.clear_output(wait=True)
    display.display(plt.gcf())


policy_net.eval()
env.reset()
state_holder.reset()
    
state_holder.push(get_screen())

total_reward = 0

for i in count():
    # Выбрать и выполнить нове действие
    action = select_action(state_holder.get_state().to(torch.float32), TEST_EPS)
    _, reward, done, _ = env.step(action.item())
    total_reward += reward
    # Получаем новое состояние
    if not done:
        state_holder.push(get_screen())
    else:
        break
    show_state(env, i)
    
print("Total game reward : {}".format(total_reward))
# Out:
# Total game reward : 98.0
